# %% [markdown]
# #Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Data Ingestion

# %%
data_path="/Workspace/Users/pontsho.seanego96@gmail.com/Bright_Retail_Store/Data source/retail_sales_dataset (4).csv"

# %%
df = pd.read_csv(data_path)
df.head(5)

# %% [markdown]
# #Data Exploratory

# %%
df.shape

# %%
df.dtypes

# %%
df.isnull().sum()

# %%
#checking number of collumns
df.columns

# %%
df["Date"].min()

# %%
df["Date"].max()

# %%
df["Product Category"].unique()

# %% [markdown]
# #Creating new usefull columns/Data processing

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.info()

# %% [markdown]
# #Visualization

# %% [markdown]
# #Exercise
# 1.Identify the worst performing product
# 2.Plot it
# 3.Bonus (Explain why it might be underperforming)

# %%
import matplotlib.pyplot as plt

# %%
df.groupby("Product Category")["Total Amount"].sum
print("Total Amount by Product Category")

# %%
    Revenue = df.groupby("Product Category")["Total Amount"].sum()
    Revenue.plot.bar()

plt.xlabel("Product Category")
plt.ylabel("Revenue")
plt.title("Revenue by Product Category")
plt.xticks(rotation=50)
plt.show()

# %%
Revenue_over_Time =df.groupby("Date")["Total Amount"].sum()

# %%
Revenue_over_Time.plot(kind="line")
plt.title("Revenue Over Time")
plt.xlabel("Date")
plt.ylabel("Revenue")
plt.show
